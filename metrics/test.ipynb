# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/harshit/Downloads/Research-Commons-Quant/automated-memetoken-index-pipeline/dataframes/dec23/1CAT.csv')

# %%
df
# Out:
#                      timestamp      open      high       low     close  \
# 0    2025-01-04 00:00:00+00:00  0.001541  0.001666  0.001541  0.001589
# 1    2025-01-03 00:00:00+00:00  0.001453  0.001551  0.001445  0.001542
# 2    2025-01-02 00:00:00+00:00  0.001449  0.001485  0.001449  0.001462
# 3    2025-01-01 00:00:00+00:00  0.001474  0.001475  0.001428  0.001429
# 4    2024-12-31 00:00:00+00:00  0.001523  0.001635  0.001471  0.001471
# ..                         ...       ...       ...       ...       ...
# 377  2023-12-24 00:00:00+00:00  0.006129  0.007218  0.006030  0.006030
# 378  2023-12-23 00:00:00+00:00  0.005577  0.006353  0.005201  0.006129
# 379  2023-12-22 00:00:00+00:00  0.004936  0.007223  0.004019  0.005575
# 380  2023-12-21 00:00:00+00:00  0.009035  0.009073  0.004441  0.004926
# 381  2023-12-20 00:00:00+00:00  0.000351  0.010325  0.000351  0.009036
#
#            volume  trades    return  log_return  cumulative_return  \
# ...

# %%
df.shape
# Out:
# (382, 14)
